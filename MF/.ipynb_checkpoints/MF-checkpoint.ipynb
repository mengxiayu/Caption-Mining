# %%
from collections import Counter
import json
from itertools import combinations
import io

from ipywidgets import interact
import ipywidgets as widgets

import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.decomposition import LatentDirichletAllocation
from sklearn.decomposition import NMF

import gensim
import gensim.downloader

sns.set(rc={'figure.figsize':(12,8)})

phrase_file = 'lecture_concepts.csv'
context_file = 'contexts_CS_410.json'

context = json.load(open(context_file, 'r'))
tid2lecNum = {}
lecNum2lecTitle = {}
for d in context:
    for c in d['contexts']:
        tid2lecNum[c['transcription']] = c['lecture_num']
        lecNum2lecTitle[c['lecture_num']] = c['lecture']

# %% [markdown]
# ### Load Data

# %%
df_phrase = pd.read_csv(phrase_file, sep='\t').fillna('')

df_phrase['lecture_number'] = df_phrase['transcriptionid'].apply(lambda x: tid2lecNum[x])

df_phrase.head(2)
# Out:
#                         transcriptionid                               videoid  \
# 0  9a443634-7f2e-4d3a-9ccd-0f1b6604c939  5d5ac9e4-567b-4ce1-a1b2-b4dd5197013c
# 1  6a9537c1-62fc-4f31-a8a7-bdfcad2f50eb  e212734f-6e3e-4124-ac91-f21ab1e126a1
#
#                                         phrases_both  \
# 0  syntagmatic relation, relation discovery, para...
# 1  topic model, probabilistic topic, text mining,...
#
#                                      phrases_caption  \
# 0  scoring function, text retrieval, similarity f...
# 1  probabilistic model, zero probability, world d...
#
#                                        phrases_video  lecture_number
# 0  similar word, paradigmatic relation discovery,...               9
# 1  topic word distribution, computation task, top...              16

# %%
lecNum2phrasesBoth = dict(
    zip(df_phrase['lecture_number'], df_phrase['phrases_both']))
lecNum2phrasesCaption = dict(
    zip(df_phrase['lecture_number'], df_phrase['phrases_caption']))
lecNum2phrasesVideo = dict(
    zip(df_phrase['lecture_number'], df_phrase['phrases_video']))

lecNum2phrasesAll = {}
word_count = Counter()
for i in range(1, 51):
    if i not in lecNum2phrasesBoth:
        lecNum2phrasesAll[i] = {
            'both': {},
            'caption': {},
            'video': {},
        }
    else:
        lecNum2phrasesAll[i] = {
            'both': lecNum2phrasesBoth[i].split(', '),
            'caption': lecNum2phrasesCaption[i].split(', '),
            'video': lecNum2phrasesVideo[i].split(', '),
        }
        word_count+=(Counter(lecNum2phrasesBoth[i].split(', ')))
        word_count+=(Counter(lecNum2phrasesCaption[i].split(', ')))
        word_count+=(Counter(lecNum2phrasesVideo[i].split(', ')))

word_count.pop('')
# Out:
# 9

# %%
# word_count.most_common(60)

# %%
word2interaction = {}
for w, c in word_count.most_common(60):
    inters = []
    for i in lecNum2phrasesAll:
        if w in lecNum2phrasesAll[i]['both']:
            inters.append(3)
        elif w in lecNum2phrasesAll[i]['caption']:
            inters.append(2)
        elif w in lecNum2phrasesAll[i]['video']:
            inters.append(1)
        else:
            inters.append(0)

    word2interaction[w] = inters

# convert to array
word2interaction = {k: np.array(word2interaction[k]) for k in word2interaction}

# %%
sns.heatmap(sorted(list(word2interaction.values()), key=lambda x: (x*np.arange(len(x))).sum()))
plt.show()

# %%
# build w2v model
glove_vectors = gensim.downloader.load('glove-twitter-25')

# %% [markdown]
# ### NMF

# %%
# run NMF
# model selection 
criteria = [] # [(N, loss)]
X = np.array(list(word2interaction.values()))

for N in range(6, 7):
    # N = 6
    model = NMF(n_components=N, init='random', random_state=0).fit(X)
    criteria.append((N, model.reconstruction_err_))

criteria = sorted(criteria, key=lambda x: x[1], reverse=True)

N = criteria[0][0]
model = NMF(n_components=N, init='random', random_state=0).fit(X)
W = model.fit_transform(X)
H = model.components_

# plot the loss-N graph
sns.lineplot(x=[n for n, c in criteria], y=[c for n, c in criteria])
plt.show()

# %%
# visualization for phrases
# phrase topics
phrases = np.array(list(word2interaction.keys()))
topic2phrases = {}
topic2weights = {}
topicIdx = W.argmax(axis=1)
topicWeight = W.max(axis=1)
for i in range(N):
    topic2phrases[i] = phrases[np.where(topicIdx==i)]
    topic2weights[i] = topicWeight[topicIdx==i]
# topic2phrases

fig, axes = plt.subplots((N+1)//2, 2, figsize=(12, 8))
axes = axes.flatten()
for topicId in range(N):
    idx = topic2weights[topicId].argsort()[::-1]
    sns.barplot(x=topic2weights[topicId][idx]/topic2weights[topicId][idx].sum(), 
    y=topic2phrases[topicId][idx], ax=axes[topicId], color='cornflowerblue')
    axes[topicId].set_xlabel('topic %d'%(topicId+1))
    # axes[topicId].set_ylabel('phrases')

plt.tight_layout()
plt.show()

# %%
# visualization for lectures
# lecture topics
lectureId = np.arange(1, 51)
topic2lecId = {}
topicIdx = H.argmax(axis=0)
topicWeight = H.max(axis=0)
for i in range(N):
    topic2lecId[i] = lectureId[np.where(topicIdx==i)]
    topic2weights[i] = topicWeight[topicIdx==i]
topic2lecId

topic2lecId[0] = topic2lecId[0][3:]
topic2weights[0] = topic2weights[0][3:]
topic2lecId

fig, axes = plt.subplots((N+1)//2, 2, figsize=(12, 8))
axes = axes.flatten()
for topicId in range(N):
    # idx = topic2weights[topicId].argsort()[::-1]
    idx = np.arange(len(topic2weights[topicId]))
    sns.barplot(x=topic2weights[topicId][idx]/topic2weights[topicId][idx].sum(),
                y=topic2lecId[topicId][idx].astype(str),
                ax=axes[topicId], color='cornflowerblue')
    axes[topicId].set_xlabel('topic %d' % (topicId+1))
    axes[topicId].set_ylabel('lecture Num')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### LDA

# %%
# run NMF
# model selection 
# criteria = [] # [(N, loss)]
# X = np.array(list(word2interaction.values()))

# for N in range(6, 7):
#     # N = 6
#     model = LatentDirichletAllocation(n_components=N, random_state=0).fit(X)
#     criteria.append((N, model.reconstruction_err_))

# criteria = sorted(criteria, key=lambda x: x[1], reverse=True)
# N = criteria[0][0]

# plot the loss-N graph
# sns.lineplot(x=[n for n, c in criteria], y=[c for n, c in criteria])
# plt.show()

N = 6
model = LatentDirichletAllocation(n_components=N, random_state=0).fit(X)
W = model.fit_transform(X)
H = model.components_

# %%
# visualization for phrases
# phrase topics
phrases = np.array(list(word2interaction.keys()))
topic2phrases = {}
topic2weights = {}
topicIdx = W.argmax(axis=1)
topicWeight = W.max(axis=1)
for i in range(N):
    topic2phrases[i] = phrases[np.where(topicIdx==i)]
    topic2weights[i] = topicWeight[topicIdx==i]
# topic2phrases

fig, axes = plt.subplots((N+1)//2, 2, figsize=(12, 8))
axes = axes.flatten()
for topicId in range(N):
    idx = topic2weights[topicId].argsort()[::-1]
    sns.barplot(x=topic2weights[topicId][idx]/topic2weights[topicId][idx].sum(), 
    y=topic2phrases[topicId][idx], ax=axes[topicId], color='cornflowerblue')
    axes[topicId].set_xlabel('topic %d'%(topicId+1))
    # axes[topicId].set_ylabel('phrases')

plt.suptitle('phrases by topics')
plt.tight_layout()
plt.show()

# %%
# visualization for lectures
# lecture topics
lectureId = np.arange(1, 51)
topic2lecId = {}
topicIdx = H.argmax(axis=0)
topicWeight = H.max(axis=0)
for i in range(N):
    topic2lecId[i] = lectureId[np.where(topicIdx==i)]
    topic2weights[i] = topicWeight[topicIdx==i]
topic2lecId

topic2lecId[0] = topic2lecId[0][3:]
topic2weights[0] = topic2weights[0][3:]
topic2lecId

fig, axes = plt.subplots((N+1)//2, 2, figsize=(12, 8))
axes = axes.flatten()
for topicId in range(N):
    # idx = topic2weights[topicId].argsort()[::-1]
    idx = np.arange(len(topic2weights[topicId]))
    sns.barplot(x=topic2weights[topicId][idx]/topic2weights[topicId][idx].sum(),
                y=topic2lecId[topicId][idx].astype(str),
                ax=axes[topicId], color='cornflowerblue')
    axes[topicId].set_xlabel('topic %d' % (topicId+1))
    axes[topicId].set_ylabel('lecture Num')

plt.suptitle('lecture number by topics')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### error analysis

# %%
df_temp = pd.DataFrame({}, columns=['topic_id', 'lec_number', 'title',
                                    'phrase_both', 'phrase_caption', 'phrase_video'])

for topicNum in range(N):
    for lecNum in topic2lecId[topicNum]:
        df_temp.loc[len(df_temp)] = topicNum, lecNum, lecNum2lecTitle[lecNum], \
            lecNum2phrasesBoth[lecNum], lecNum2phrasesCaption[lecNum], lecNum2phrasesVideo[lecNum]

# df_temp.to_excel('lecture_topics.xlsx', index=False)
df_temp
# Out:
#    topic_id lec_number                                              title  \
# 0         0         17  Lecture 17 — Probabilistic Topic Models  Overv...
# 1         0         18  Lecture 18 — Probabilistic Topic Models  Overv...
# 2         0         19  Lecture 19 — Probabilistic Topic Models  Minin...
# 3         1          2  Lecture 2 — Overview Text Mining and Analytics...
# 4         1          5    Lecture 5 — Text Representation - Part 1 | UIUC
# 5         1          6    Lecture 6 — Text Representation - Part 2 | UIUC
# 6         1         30    Lecture 30 — Text Clustering  Motivation | UIUC
# 7         1         36  Lecture 36 — Text Categorization Motivation | ...
# 8         1         43  Lecture 43 — Opinion Mining and Sentiment Anal...
# 9         1         44  Lecture 44 — Opinion Mining, Sentiment Analysi...
# 10        1         46  Lecture 46 — Opinion Mining and Sentiment Anal...
# 11        1         47  Lecture 47 — Opinion Mining and Sentiment Anal...
# 12        1         48          Lecture 48 — Text Based Prediction | UIUC
# 13        1         49  Lecture 49 — Contextual Text Mining  Motivatio...
# 14        2          7  Lecture 7 — Word Association Mining and Analys...
# 15        2          8  Lecture 8 — Paradigmatic Relation Discovery - ...
# 16        2          9  Lecture 9 — Paradigmatic Relation Discovery - ...
# 17        2         10  Lecture 10 — Syntagmatic Relation Discovery  E...
# 18        2         11  Lecture 11 — Syntagmatic Relation Discovery  C...
# 19        2         12  Lecture 12 — Syntagmatic Relation Discovery  M...
# 20        2         13  Lecture 13 — Syntagmatic Relation Discovery  M...
# 21        2         14  Lecture 14 — Topic Mining and Analysis  Motiva...
# 22        3         15  Lecture 15 — Topic Mining and Analysis  Term a...
# 23        3         22  Lecture 22 — Probabilistic Topic Models  Mixtu...
# 24        3         26  Lecture 26 — Probabilistic Latent Semantic Ana...
# 25        3         27  Lecture 27 — Probabilistic Latent Semantic Ana...
# 26        3         28  Lecture 28 — Latent Dirichlet Allocation LDA -...
# 27        3         31  Lecture 31 — Text Clustering Generative Probab...
# 28        3         32  Lecture 32 — Text Clustering Generative Probab...
# 29        3         33  Lecture 33 — Text Clustering Generative Probab...
# 30        3         34  Lecture 34 — Text Clustering Similarity based ...
# 31        3         38  Lecture 38 — Text Categorization Generative Pr...
# 32        3         50  Lecture 50 — Contextual Text Mining  Contextua...
# 33        4         35    Lecture 35 — Text Clustering  Evaluation | UIUC
# 34        4         37   Lecture 37 — Text Categorization  Methods | UIUC
# 35        4         39  Lecture 39 — Text Categorization  Discriminati...
# 36        4         40  Lecture 40 — Text Categorization  Discriminati...
# 37        4         41  Lecture 41 — Text Categorization  Evaluation -...
# 38        4         42  Lecture 42 — Text Categorization  Evaluation -...
# 39        4         45  Lecture 45 — Opinion Mining and Sentiment Anal...
# 40        5         16  Lecture 16 — Topic Mining and Analysis  Probab...
# 41        5         20  Lecture 20 — Probabilistic Topic Models  Mixtu...
# 42        5         21  Lecture 21 — Probabilistic Topic Models  Mixtu...
# 43        5         23  Lecture 23 — Probabilistic Topic Models  Expec...
# 44        5         24  Lecture 24 — Probabilistic Topic Models  Expec...
# 45        5         25  Lecture 25 — Probabilistic Topic Models  Expec...
# 46        5         29  Lecture 29 — Latent Dirichlet Allocation LDA -...
#
#                                           phrase_both  \
# 0   language model, topic model, probabilistic top...
# 1    language model, maximum likelihood, topic mining
# 2   maximum likelihood estimate, topic model, like...
# 3                                         text mining
# 4
# 5
# 6                                     text clustering
# 7                                 text categorization
# 8                  opinion mining, sentiment analysis
# 9             text categorization, sentiment analysis
# 10                 opinion mining, sentiment analysis
# 11                 opinion mining, sentiment analysis
# 12
# 13  text mining, contextual text mining, contextua...
# 14                                   word association
# 15          relation discovery, paradigmatic relation
# 16  syntagmatic relation, relation discovery, para...
# 17           syntagmatic relation, relation discovery
# 18  conditional entropy, syntagmatic relation, rel...
# 19  mutual information, syntagmatic relation, rela...
# 20  mutual information, syntagmatic relation, rela...
# 21                                       topic mining
# 22                                       topic mining
# 23                                      mixture model
# 24
# 25
# 26                                    prior knowledge
# 27  document clustering, probabilistic model, mixt...
# 28  text clustering, probabilistic model, likeliho...
# 29  document clustering, text clustering, probabil...
# 30                                    text clustering
# 31  document clustering, text categorization, prob...
# 32  text mining, contextual text, contextual text ...
# 33                                    text clustering
# 34     text categorization, discriminative classifier
# 35  text categorization, logistic regression, disc...
# 36     text categorization, discriminative classifier
# 37
# 38                                text categorization
# 39            logistic regression, sentiment analysis
# 40  topic model, probabilistic topic, text mining,...
# 41  topic model, unigram language model, backgroun...
# 42  probabilistic topic model, probabilistic topic...
# 43  probabilistic topic model, topic model, probab...
# 44
# 45
# 46  probabilistic topic model, topic model, probab...
#
#                                        phrase_caption  \
# 0   maximum likelihood estimate, likelihood estima...
# 1   maximum likelihood estimate, likelihood estima...
# 2   objective function, optimization problem, unig...
# 3   language processing, opinion mining, word asso...
# 4   language processing, text mining, sentiment an...
# 5   language processing, text mining, text object,...
# 6   topic model, clustering result, text mining, t...
# 7   training example, information retrieval, categ...
# 8   text mining, natural language, opinion holder,...
# 9   language processing, text mining, text object,...
# 10  topic model, bayesian inference, maximum likel...
# 11  generative model, topic model, text categoriza...
# 12  text mining, contextual text, opinion mining, ...
# 13          opinion mining, data mining, topic mining
# 14  text retrieval, discover syntagmatic relation,...
# 15  text retrieval, similarity function, informati...
# 16  scoring function, text retrieval, similarity f...
# 17  random variable, word association, discover sy...
# 18  random variable, mutual information, word asso...
# 19  random variable, conditional entropy, discover...
# 20  maximum likelihood estimate, likelihood estima...
# 21  syntagmatic relation, data mining, paradigmati...
# 22  scoring function, topic coverage, word associa...
# 23  objective function, background model, backgrou...
# 24  background model, topic model, background lang...
# 25  hidden variable, background language model, un...
# 26  topic model, background language model, backgr...
# 27  topic model, world distribution, topic coverag...
# 28  topic model, unigram language model, document ...
# 29  topic model, hidden variable, unigram language...
# 30  objective function, similarity function, mixtu...
# 31  background model, topic word distribution, uni...
# 32  text retrieval, information retrieval, probabi...
# 33  similarity function, training data, mixture mo...
# 34  objective function, optimization problem, trai...
# 35  objective function, training example, optimiza...
# 36  objective function, topic model, training exam...
# 37      information retrieval, categorization problem
# 38           machine learning, categorization problem
# 39  scoring function, training data, logistical re...
# 40  probabilistic model, zero probability, world d...
# 41  maximum likelihood estimate, likelihood estima...
# 42  objective function, background model, topic wo...
# 43  background model, maximum likelihood estimate,...
# 44  background model, hidden variable, topic word ...
# 45  hidden variable, mixture model, parameter valu...
# 46  background model, maximum likelihood estimate,...
#
#                                          phrase_video
# 0   unigram lm, simple language, simple language m...
# 1    statistical language, statistical language model
# 2   mining one topic, simple case, one topic, topi...
# 3                 overview text mining, overview text
# 4                                 text representation
# 5                                 text representation
# 6
# 7   keyword text, predefined category, multiple un...
# 8         different kind, implicit holder, text datum
# 9   task definition, text feature, sentiment class...
# 10  motivation hotel, stage aspect segmentation, a...
# 11  user rating behavior, aspect rating analysis, ...
# 12  joint mining, main task, world variable conten...
# 13         interesting question, context partitioning
# 14  association mining, basic word relation, word ...
# 15  word context, paradigmatic relation discovery,...
# 16  similar word, paradigmatic relation discovery,...
# 17                     syntagmatic relation discovery
# 18  syntagmatic relation discovery, complete defin...
# 19  syntagmatic relation discovery, different prob...
# 20  information part, syntagmatic relation discove...
# 21                 task definition, formal definition
# 22                         collection c, topical term
# 23  topic model, model estimation, probabilistic t...
# 24  mixed topic, ml parameter, latent semantic ana...
# 25  probabilistic latent, latent semantic analysis...
# 26  latent dirichlet, dirichlet allocation, latent...
# 27    generative probabilistic model, generative mode
# 28  cluster allocation, generative probabilistic m...
# 29        ml estimate, generative probabilistic model
# 30                                       general idea
# 31  naive baye classifier, generative probabilisti...
# 32  content variation, impact analysis, event impa...
# 33  text cluster, indirect evaluation, direct eval...
# 34                              categorization method
# 35  classifier part, discriminative classifier par...
# 36  categorization method, linear svm, soft margin...
# 37  classification accuracy, general evaluation, c...
# 38         evaluation part, categorization evaluation
# 39  ordinal logistic regression, rating prediction...
# 40  topic word distribution, computation task, top...
# 41                  two unigram language, two unigram
# 42  mixture model estimation, model estimation, on...
# 43                             maximization algorithm
# 44  maximization algorithm, topic model, probabili...
# 45  topic model, maximization algorithm, probabili...
# 46  latent dirichlet, dirichlet allocation, parame...

# %% [markdown]
# ### interactive NMF

# %%
def plot_topics(n=6):
    # run NMF
    N = n
    X = np.array(list(word2interaction.values()))
    model = NMF(n_components=N, init='random', random_state=0)
    W = model.fit_transform(X)
    H = model.components_

    # visualization for phrases
    # phrase topics
    phrases = np.array(list(word2interaction.keys()))
    topic2phrases = {}
    topic2weights = {}
    topicIdx = W.argmax(axis=1)
    topicWeight = W.max(axis=1)
    for i in range(N):
        topic2phrases[i] = phrases[np.where(topicIdx == i)]
        topic2weights[i] = topicWeight[topicIdx == i]
    # topic2phrases

    fig, axes = plt.subplots(N, 2, figsize=(12, 8*2))
    # fig.canvas.width = '100%'
    # fig.canvas.height = '500px'
    # axes = axes.flatten()

    for topicId in range(N):
        idx = topic2weights[topicId].argsort()[::-1]
        sns.barplot(x=topic2weights[topicId][idx]/topic2weights[topicId][idx].sum(),
                    y=topic2phrases[topicId][idx], ax=axes[topicId][0], color='cornflowerblue')
        axes[topicId][0].set_xlabel('topic %d' % (topicId+1))
        axes[topicId][0].set_ylabel('phrases')

    # visualization for lectures
    # lecture topics
    lectureId = np.arange(1, 51)
    topic2lecId = {}
    topicIdx = H.argmax(axis=0)
    topicWeight = H.max(axis=0)
    for i in range(N):
        topic2lecId[i] = lectureId[np.where(topicIdx==i)]
        topic2weights[i] = topicWeight[topicIdx==i]
    topic2lecId

    topic2lecId[0] = topic2lecId[0][3:]
    topic2weights[0] = topic2weights[0][3:]
    topic2lecId

    for topicId in range(N):
        # idx = topic2weights[topicId].argsort()[::-1]
        idx = np.arange(len(topic2weights[topicId]))
        sns.barplot(x=topic2weights[topicId][idx]/topic2weights[topicId][idx].sum(),
                    y=topic2lecId[topicId][idx].astype(str),
                    ax=axes[topicId][1], color='cornflowerblue')
        axes[topicId][1].set_xlabel('topic %d' % (topicId+1))
        axes[topicId][1].set_ylabel('lecture Num')

    # plt.tight_layout()
    # plt.show()

def test(n=4):
    print(n)
    # pass
    # return n

# %%
_ = interact(plot_topics, n=widgets.IntSlider(min=2, max=10, step=1, value=6));
# Out:
# interactive(children=(IntSlider(value=6, description='n', max=10, min=2), Output()), _dom_classes=('widget-int…
